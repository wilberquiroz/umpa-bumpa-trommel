# %%
import pandas as pd

# %%
print("hello")
# Out:
# Running cells with '.venv (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/centraal-w/Desktop/WolkenMelodie/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
